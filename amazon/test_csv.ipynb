# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('amazon_list1.csv')
pd.set_option('display.max_colwidth', None)
data.head(30)
# Out:
#                                                                                                                                                                                                  Name  \
# 0                                                                                                                                                         bliss Triple Oxygen Instant Energizing Mask
# 1                                                                                                               Yes To Cucumbers Face Kit (Soothing Eye Gel, Gel Cleanser, Daily Calming Moisturizer)
# 2                                                                                 Freeman Facial Mask Variety Bundle for Skin Care, Peel Off Face Masks with Clay + Dead Sea Minerals 6 fl oz, 4 Pack
# ...

# %%
data[data['Produts_benefits'].isnull()]
# Out:
#                                                                                                                                                                                                           Name  \
# 0                                                                                                                                                                  bliss Triple Oxygen Instant Energizing Mask
# 1                                                                                                                        Yes To Cucumbers Face Kit (Soothing Eye Gel, Gel Cleanser, Daily Calming Moisturizer)
# 2                                                                                          Freeman Facial Mask Variety Bundle for Skin Care, Peel Off Face Masks with Clay + Dead Sea Minerals 6 fl oz, 4 Pack
# ...

# %%
np.array(data)
# Out:
# array([['bliss Triple Oxygen Instant Energizing Mask',
#         'https://images-na.ssl-images-amazon.com/images/I/31L0Sl092AL._SX342_SY445_QL70_ML2_.jpg',
#         'https://www.amazon.com/bliss-Triple-Oxygen-Instant-Energizing/dp/B000JUK1D2/ref=sr_1_37?crid=2TNB8V67U9FMK&keywords=skincare+products&qid=1654853304&rnid=2941120011&s=beauty&sprefix=skincare+products%2Caps%2C481&sr=1-37',
#         ..., '(None,)', nan, nan],
#        ['Yes To Cucumbers Face Kit (Soothing Eye Gel, Gel Cleanser, Daily Calming Moisturizer)',
#         'https://images-na.ssl-images-amazon.com/images/I/41cw8JBpiML._SX300_SY300_QL70_ML2_.jpg',
#         'https://www.amazon.com/Yes-Cucumbers-Soothing-Cleanser-Moisturizer/dp/B07BKFRN32/ref=sr_1_36?crid=2TNB8V67U9FMK&keywords=skincare+products&qid=1654853304&rnid=2941120011&s=beauty&sprefix=skincare+products%2Caps%2C481&sr=1-36',
#         ..., '(None,)', nan, nan],
# ...
